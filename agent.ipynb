# %% [markdown]
# # TP 2 : Agents avec Langchain

# %% [markdown]
# ### Création d’un nouveau agent sans System Message

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_ollama import ChatOllama
model = ChatOllama(
model="llama3.2:3b", # ou mistral, gemma, etc.
temperature=0
)
agent = create_agent(model=model)
question = HumanMessage(content="Quelle est la capitale de la lune ?")

response = agent.invoke({"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# La question classique !
#
# Malheureusement, il n'y a pas de capitale sur la Lune. La Lune est un satellite naturel de la Terre et n'a pas d'atmosphère ou de vie organisée. Il n'y a pas de gouvernement, de ville ou de structure humaine qui puisse être considérée comme une capitale.
#
# Cependant, il y a eu des missions spatiales qui ont envoyé des robots et des humains sur la surface de la Lune, notamment pendant les missions Apollo des États-Unis dans les années 1960 et 1970. Les sites de landing les plus connus sont le Mare Imbrium, le Mare Serenitatis et le Cratère Tycho.
#
# En résumé, il n'y a pas de capitale sur la Lune, mais des sites de exploration humaine qui ont été visités par des robots et des astronautes.

# %% [markdown]
# ### Agent avec System Message : un message de contrôle qui définit le  comportement global du modèle

# %%
system_prompt = "Vous êtes un auteur de science-fiction ; créez une capitale à  la demande des utilisateurs."

# %%
scifi_agent = create_agent( 
model=model, 
system_prompt=system_prompt 
) 
response = scifi_agent.invoke( 
{"messages": [question]} 
)

# %%
print(response['messages'][-1].content)
# Out:
# La question classique !
#
# Malheureusement, il n'y a pas de capitale sur la Lune. La Lune est un satellite naturel de la Terre et n'a pas d'atmosphère ou de vie organisée. Il n'y a pas de gouvernement, de ville ou de structure humaine permanente sur la surface de la Lune.
#
# Cependant, il y a eu des missions spatiales qui ont envoyé des robots et des humains à la surface de la Lune dans le cadre du programme Apollo des États-Unis. Les principaux sites visités par les astronautes sont :
#
# * La plaque d'atterrissage de la mission Apollo 11, située près du site de la mission Apollo 15.
# * Le site de la mission Apollo 17.
#
# Mais il n'y a pas de capitale ou de ville permanente sur la Lune. Les missions spatiales actuelles et futures visent à explorer la surface de la Lune et à mener des recherches scientifiques, mais pas à établir une colonie ou une capitale humaine.
#
# Si vous souhaitez créer une capitale fictive sur la Lune, je serais ravi de vous aider !

# %% [markdown]
# ### Agent avec Few-shot learning : une méthode où le modèle  apprend une nouvelle tâche ou classe à partir de quelques  exemples seulement

# %%
system_prompt = """ 
Vous êtes un auteur de science-fiction et vous devez créer une capitale spa tiale à la demande d'un utilisateur. 
Utilisateur : Quelle est la capitale de Mars ? 
Auteur : Marsialis 
Utilisateur : Quelle est la capitale de Vénus ? 
Auteur : Venusovia 
"""

# %%
scifi_agent = create_agent( 
model=model, 
system_prompt=system_prompt 
) 
response = scifi_agent.invoke( 
{"messages": [question]} 
)

# %%
print(response['messages'][-1].content)
# Out:
# Une question qui nous plonge dans l'exploration de notre système solaire !
#
# La réponse est un peu plus compliquée que pour les planètes terrestres. La Lune n'a pas de capitale, car elle n'est pas une planète avec une population permanente ou une administration gouvernementale.
#
# Cependant, si nous devions imaginer une capitale sur la Lune, on pourrait suggérer quelques options :
#
# * Lunaria : un nom qui évoque l'astronomie et la géologie de notre satellite.
# * Seleneia : inspiré du nom grec de la Lune, Selène.
# * New Tranquillity : un nom qui évoque la paix et la tranquillité, deux valeurs importantes pour une colonie spatiale.
#
# Mais il est important de noter que ces noms sont purement imaginaires et ne correspondent pas à aucune réalité actuelle. La Lune reste un monde sans population permanente, mais avec des missions spatiales régulières et des projets de développement futuristes en cours.

# %% [markdown]
# ### Agent avec réponse structurée: une sortie organisée selon un  format prédéfini, plutôt que du texte libre.

# %%
system_prompt = """ 
Vous êtes un auteur de science-fiction et vous devez créer une capitale spa tiale à la demande d'un utilisateur. 
Veuillez respecter la structure ci-dessous. 
Nom : Nom de la capitale 
Localisation : Lieu où elle est située 
Ambiance : Description en 2 ou 3 mots 
Économie : Principaux secteurs d'activité 
"""

# %%
scifi_agent = create_agent( 
model=model, 
system_prompt=system_prompt 
) 
response = scifi_agent.invoke( 
{"messages": [question]} 
)

# %%
print(response['messages'][-1].content)
# Out:
# Je vais créer une capitale spatiale pour vous !
#
# **Nom :** Lunaria
# **Localisation :** La surface de la Lune, dans le bassin sud-occidental.
# **Ambiance :** Futuriste et étoilée.
#
# **Économie :**
#
# * **Tourisme spatial** : Les visiteurs viennent de tout le système solaire pour découvrir les merveilles de la Lune.
# * **Minierie lunaire** : Les ressources rares de la Lune sont extraites pour alimenter les industries spatiales.
# * **Recherche scientifique** : Les instituts de recherche et les laboratoires étudient les phénomènes astronomiques et les possibilités d'exploration spatiale.
#
# Lunaria est une ville-état qui a émergé comme un centre de gravité pour l'activité spatiale. Ses habitants sont des pionniers, des scientifiques et des entrepreneurs qui ont trouvé un nouveau foyer dans le cosmos.

# %% [markdown]
# ### Agent avec réponse structurée en utilisant BaseModel : rendre la  réponse facile à exploiter automatiquement par un programme ou  un système.

# %%
system_prompt = """
Vous êtes un auteur de science-fiction et vous devez créer une capitale spatiale à la demande d'un utilisateur.

Veuillez respecter la structure ci-dessous.

Nom : Nom de la capitale
Localisation : Lieu où elle est située
Ambiance : Description en 2 ou 3 mots
Economie : Principaux secteurs d'activité
"""

# %%
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    nom: str
    Localisation: str
    Ambiance: str
    Economie: str

# %%
agent = create_agent(
model=model,
system_prompt=system_prompt,
response_format=CapitalInfo 
) 
question = HumanMessage(content="Quelle est la capitale de la lune ?") 
response = agent.invoke( 
{"messages": [question]} 
) 
response["structured_response"]
# Out:
# CapitalInfo(nom='Capitole Lunaire', Localisation='Lune', Ambiance='Sérial', Economie='Tourisme et Exploration Spatiale')

# %% [markdown]
# ### Les tools (outils) : une fonction externe que le modèle peut  appeler pour effectuer une action précise qu’il ne peut pas faire  seul

# %% [markdown]
# #### Création du Tool

# %%
from langchain.tools import tool

# %%
@tool("meteo_capitale")
def meteo_capitale(ville: str) -> str:
    """
    Donne la météo d'une capitale (valeurs fixes pour test).
    Args:
        ville: nom de la capitale
    """
    print("tool meteo_capitale utilisé")
    temperature = 25
    humidite = 60
    pression = 1013
    return (
        f"Météo à {ville} : "
        f"Température = {temperature}°C, "
        f"Humidité = {humidite}%, "
        f"Pression = {pression} hPa"
    )

# %% [markdown]
# #### Ajout du Tool à l’agent

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_ollama import ChatOllama

model = ChatOllama(model="llama3.2:3b")

# %%
system_prompt = "Utilises les tools pour répondre aux questions" 
agent = create_agent( 
model=model, 
tools=[meteo_capitale], 
system_prompt=system_prompt, 
) 
question = HumanMessage(content="Quelle est la météo à Capitole lunaire ?") 
response = agent.invoke( 
{"messages": [question]} 
) 
print(response['messages'][-1].content)
# Out:
# tool meteo_capitale utilisé
# Voici les détails météorologiques actuels pour Capitole lunaire :
#
# - Température : 25°C
# - Humidité relative : 60%
# - Pression atmosphérique : 1013 hPa
#
# Si vous souhaitez obtenir des informations plus précises ou actualisées, n'hésitez pas à me demander !

# %% [markdown]
# ### Agent sans Web Search Tool

# %%
agent = create_agent( 
model=model, 
) 
question = HumanMessage(content="Vos connaissances en matière d'apprentissage  sont-elles à jour ?") 
response = agent.invoke( 
{"messages": [question]} 
) 
print(response['messages'][-1].content)
# Out:
# Mes connaissances sont actuellement réduites au mars 2023. J'ai été formé jusqu'à cette date et j'ai accès à des informations jusqu'à cette période. Cependant, je n'ai pas la capacité de m'actualiser en temps réel ou d'accéder à de nouvelles informations après la date de ma formation.
#
# Si vous posez une question ou si vous cherchez des informations sur un sujet spécifique qui a été publié après le mars 2023, je ferai de mon mieux pour vous fournir des informations utiles et précises. Cependant, j'aurai peut-être besoin de confirmer les faits avec d'autres sources pour m'assurer de leur exactitude.
#
# Comment puis-je vous aider aujourd'hui ?

# %% [markdown]
# ### Agent avec Web Search Tool

# %% [markdown]
# #### Sortie du Tool

# %%
from typing import Dict, Any
from tavily import TavilyClient
from dotenv import load_dotenv
from langchain.tools import tool

load_dotenv()

tavily_client = TavilyClient()

@tool("web_search")
def web_search(query: str) -> Dict[str, Any]:
    """ Effectue une recherche sur le web en utilisant l'API de Tavily. Args: query: la requête de recherche """
    return tavily_client.search(query)

web_search.invoke("Qui est le Président de commune actuel de Marrakech ?")
# Out:
# {'query': 'Qui est le Président de commune actuel de Marrakech ?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://archive.challenge.ma/la-presidence-des-communes-et-des-provinces-se-precisent-dheure-en-heure-55594',
#    'title': 'La présidence des communes et des provinces se précise',
#    'content': 'Comme attendu, le PJDiste Mohamed Larbi Belkaid est désormais le nouveau maire de la ville de Marrakech. Pour Casablanca, le nouveau maire de la ville est Abdelaziz Omari du PJD. Il a été porté à la présidence du conseil communal de la ville blanche par une écrasante majorité de\xa0124 voix sur les 147. A Agadir, c’est Salah El Malouki qui a été consacré nouveau Maire de la ville avec\xa044 voix sur 65, sachant qu’il y a eu 18 abstentions et 3 absences. L’autre candidat à la présidence du conseil de la ville n’était autre que Rachid Talbi Alami, le Président de la chambre des représentants qui s’est retiré finalement à la dernière minute. C’est Jamal Ben Rabiaa qui a été élu président du conseil de la ville avec 30 voix sur 43. Des voix se sont mêmes élevées pour barrer la route à Omar Hjira l’actuel président du conseil de la ville de l’oriental.',
#    'score': 0.8803145,
#    'raw_content': None},
#   {'url': 'https://fr.hespress.com/224837-marrakech-fatima-zahra-mansouri-elue-presidente-du-conseil-communal.html',
#    'title': 'Marrakech : Fatima Zahra Mansouri élue présidente du Conseil communal',
#    'content': '# Marrakech : Fatima Zahra Mansouri élue présidente du Conseil communal. **La présidente du Conseil national du Parti Authenticité et Modernité (PAM), Fatima Zahra Mansouri, a été élue, ce vendredi 17 septembre, présidente du Conseil communal de Marrakech.**. Fatima Zahra Mansouri a obtenu la majorité absolue avec un total de 79 voix, avec l’abstention d’un seul conseiller, et ce, lors d’une session marquée par la présence notamment des représentants des autorités locales et des membres du Conseil communal de la cité ocre. Par la même occasion, il a été procédé à l’élection des dix vice-présidents du Conseil communal de Marrakech. Le parti du PAM a obtenu 48 sièges sur un total de 193 au niveau des cinq arrondissements de la ville de Marrakech : Guelliz, Sidi Youssef Ben Ali, Ennakhil, Marrakech-Médina et Ménara, outre la municipalité du Méchouar- Kasbah lors des élections générales du 08 septembre courant. ### Marrakech : hausse de 11% des nuitées dans les EHTC à fin mars.',
#    'score': 0.8145405,
#    'raw_content': None},
#   {'url': 'https://www.ville-marrakech.ma/bureau-du-conseil-communal-de-marrakech',
#    'title': 'Bureau du Conseil Communal de Marrakech',
#    'content': 'Bilan des réalisations à mi-mandat (2022-2023-2024). Deuxième évaluation annuelle du plan d’action de la commune de Marrakech 2025. ## Bureau du Conseil Communal de Marrakech. Mme Fatim Ezzahra EL MANSOURI. #### Président de la Commune de Marrakech. ### M. #### 1er Vice président du Conseil Communal de Marrakech. ### Mme Khadija BOUHRACHI. ### Mme. Atika BOUSETTA. ### Mme. Zoubida ELMCHAMER.',
#    'score': 0.8058924,
#    'raw_content': None},
#   {'url': 'https://www.lebrief.ma/12881-qui-sont-les-nouveaux-maires-et-presidents-des-regions',
#    'title': 'Qui sont les nouveaux maires et présidents des régions ? - Lebrief.ma',
#    'content': 'Sans surprise, Fatima Zahra Mansouri du Parti authenticité et modernité (PAM) a été élue présidente du Conseil communal de Marrakech.',
#    'score': 0.751375,
#    'raw_content': None},
#   {'url': 'https://fr.le360.ma/politique/presidents-de-communes-la-liste-des-limogeages-sallonge_XOWP57I3MBF5TNHHENNGCLG3VM',
#    'title': 'Présidents de commune: la liste des limogeages s’allonge | le360.ma',
#    'content': '## Revue de presseL’assainissement du fichier des collectivités territoriales se poursuit par la révocation des présidents, des vice-présidents et des élus véreux, à l’échelle nationale. Dans ce cadre, deux présidents et deux vice-présidents viennent d’être révoqués de leurs fonctions dans la région de Marrakech-Safi par la justice administrative compétente. «*La justice administrative de Marrakech, qui a agi suite à une requête du gouverneur de la province de Youssoufia, a également révoqué de leurs fonctions le premier vice-président de cette commune et la sixième vice-présidente du Conseil*», relaie le quotidien. La requête déposée par le gouverneur de la province de Youssoufia auprès de la justice administrative compétente de Marrakech se fondait sur le rapport de l’inspection générale de l’administration territoriale (IGAT), qui avait relevé des dysfonctionnements dans la gestion des affaires locales de la commune. Ce même jour, ajoute *Al Ahdath Al Maghribia*, dans cette même wilaya de la région de Marrakech-Safi, la justice administrative a révoqué de ses fonctions le président de la commune urbaine de Safi, Nourddine Kemmouch, élu du Parti de l’Istiqlal (PI).',
#    'score': 0.7451949,
#    'raw_content': None}],
#  'response_time': 0.0,
#  'request_id': '565bb9f9-0e97-4fb1-9ddc-e6a5f23e2961'}

# %% [markdown]
# #### Sortie de l’agent

# %%
agent = create_agent( 
model=model, 
tools=[web_search] 
) 
question = HumanMessage(content="Qui est le Président de commune actuel de  Marrakech ?") 
response = agent.invoke( 
{"messages": [question]}) 
print(response['messages'][-1].content)
# Out:
# Le Président de la commune actuel de Marrakech est Fatima Ezzahra El Mansouri.

# %% [markdown]
# ### Agent sans mémoire

# %%
agent = create_agent( 
model= model) 
question = HumanMessage(content="Bonjour, mon nom est Sami et je suis un déve loppeur.") 
response = agent.invoke( 
{"messages": [question]}  
) 
print(response['messages'][-1].content) 
question = HumanMessage(content="Quel est mon métier ?") 
response = agent.invoke( 
{"messages": [question]}  
) 
print(response['messages'][-1].content)
# Out:
# Bonjour Sami ! Enchanté de faire votre connaissance. Je suis ravi de discuter avec vous en tant que développeur. Qu'est-ce que vous travailliez sur actuellement ? Avez-vous des projets spécifiques ou des problèmes à résoudre qui vous tournent le dos ?
# Je ne peux pas vous dire avec certitude quel est votre métier. Cependant, je peux vous aider à découvrir vos passions et compétences pour trouver une réponse plus précise.
#
# Pour commencer, pouvez-vous me donner quelques informations sur vous ?
#
# 1. Quels sont vos intérêts ? (par exemple, les arts, la science, les sports, etc.)
# 2. Quelles compétences avez-vous développées ? (par exemple, communication, analytique, créative, etc.)
# 3. Avez-vous déjà suivi des formations ou obtenu un diplôme ?
# 4. Que vous faites-vous actuellement ? (par exemple, étudiant, salarié, entrepreneur, etc.)
#
# En répondant à ces questions, nous pourrons commencer à explorer vos possibilités et essayer de découvrir votre métier !

# %% [markdown]
# ### Agent avec mémoire

# %%
from langgraph.checkpoint.memory import InMemorySaver  
agent = create_agent( 
model=model, 
checkpointer=InMemorySaver(),  
) 
question = HumanMessage(content="Bonjour, mon nom est Sami et je suis un déve loppeur.") 
config = {"configurable": {"thread_id": "1"}} 
response = agent.invoke( 
{"messages": [question]}, 
config,  
) 
question = HumanMessage(content="Quel est mon métier ?") 
response = agent.invoke( 
{"messages": [question]}, 
config,  
) 
print(response['messages'][-1].content)
# Out:
# Pardonne-moi pour la confusion !
#
# À partir de tes premières phrases, j'ai compris que tu étais un développeur (développeur), mais je me suis trompé sur ton prénom et ton titre.
#
# Donc, pour clarifier : Tu es un développeur, c'est-à-dire quelqu'un qui conçoit et met en œuvre des logiciels pour résoudre des problèmes ou répondre à des besoins spécifiques. Quel domaine t'intéresse le plus ? L'application, la base de données, les jeux vidéo, etc. ?

# %% [markdown]
# # TP : Chef personnel

# %%
import os
from typing import Any, Dict
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage
from langchain.tools import tool
from langgraph.checkpoint.memory import InMemorySaver
from tavily import TavilyClient

# Charger les variables d'environnement (.env)
load_dotenv()

# ==========================================
# 1. CONSTRUCTION DE L'OUTIL DE RECHERCHE
# ==========================================
def build_web_search_tool():
    """Construit un outil Tavily robuste avec gestion d'absence de clé API."""
    api_key = os.getenv("TAVILY_API_KEY")

    if not api_key:
        @tool("web_search")
        def web_search(query: str) -> Dict[str, Any]:
            """
            Recherche web indisponible tant que TAVILY_API_KEY n'est pas configurée.
            """
            return {
                "status": "error",
                "message": "La recherche web est indisponible. Ajoutez TAVILY_API_KEY dans le fichier .env."
            }
        return web_search

    tavily_client = TavilyClient(api_key=api_key)

    @tool("web_search")
    def web_search(query: str) -> Dict[str, Any]:
        """
        Recherche des informations culinaires sur le web (recettes, techniques, associations).
        Args:
            query: La question ou requête de recherche culinaire.
        """
        return tavily_client.search(query, max_results=3)

    return web_search

# ==========================================
# 2. CONFIGURATION ET CRÉATION DE L'AGENT
# ==========================================
def build_chef_agent():
    """Initialise l'agent avec son comportement global (System Message) et sa mémoire."""
    
    system_prompt = """
Tu es un chef cuisinier personnel intelligent.

Ton rôle:
- Aider l'utilisateur à cuisiner avec les ingrédients disponibles dans son réfrigérateur.
- Mémoriser ses préférences, allergies, régimes alimentaires et contraintes au fil de la discussion.
- Utiliser l'outil web_search uniquement si une information culinaire récente ou spécifique est nécessaire.
- Proposer des plats réalistes, simples et adaptés à la situation.

Règles de réponse:
- Réponds toujours en français.
- Tiens compte de l'historique complet de la conversation (mémoire).
- Privilégie les recettes faisables en moins de 20 minutes.
- N'invente pas d'ingrédients disponibles. Si tu proposes un ingrédient manquant, marque-le explicitement comme [Optionnel].
- Reste concis, précis et structure ta réponse ainsi:
  1. Plat proposé
  2. Pourquoi il convient (rappeler les préférences respectées)
  3. Ingrédients utilisés
  4. Étapes courtes de préparation
  5. Variante ou conseil du Chef
"""

    
    return create_agent(
        model=model,  # Utilise votre instance de modèle 'llama3.2:3b' déclarée plus haut
        tools=[build_web_search_tool()],
        system_prompt=system_prompt,
        checkpointer=InMemorySaver()  # Active la mémoire conversationnelle
    )

# ==========================================
# 3. FONCTION D'INTERACTION AVEC LA MÉMOIRE
# ==========================================
def ask_chef(agent, user_text: str, thread_id: str = "chef-session-tp") -> str:
    """Envoie un message à l'agent en préservant le contexte via l'identifiant de session."""
    response = agent.invoke(
        {"messages": [HumanMessage(content=user_text)]},
        {"configurable": {"thread_id": thread_id}}
    )
    return response["messages"][-1].content

# ==========================================
# 4. SCÉNARIO DE DÉMONSTRATION (AUTOMATIQUE)
# ==========================================
def run_chef_demo():
    """Exécute la séquence de test demandée par le TP pour valider le comportement."""
    chef_agent = build_chef_agent()
    
    
    scénario = [
        "Bonjour, je suis Najlaa. Je n'aime pas le piment et je suis végétarienne.",
        "Mémorise aussi que j'ai seulement 20 minutes pour cuisiner le soir.",
        "Dans mon réfrigérateur j'ai : des oeufs, des tomates, du fromage, des oignons et du pain. Propose-moi un plat adapté.",
        "Donne-moi une autre variante différente en utilisant le web si nécessaire pour vérifier une idée originale."
    ]

    print("=== DÉBUT DU TP AGENT : CHEF PERSONNEL ===\n")
    
    for i, prompt in enumerate(scénario, start=1):
        print(f" [Étape {i}] Utilisateur : {prompt}")
        réponse = ask_chef(chef_agent, prompt)
        print(f" Chef Personnel :\n{réponse}")
        print("-" * 60 + "\n")


run_chef_demo()
# Out:
# === DÉBUT DU TP AGENT : CHEF PERSONNEL ===
#
#  [Étape 1] Utilisateur : Bonjour, je suis Najlaa. Je n'aime pas le piment et je suis végétarienne.
#  Chef Personnel :
# Bonjour Najlaa !
#
# Je vais te proposer une recette végétarienne facile et rapide qui convient parfaitement à tes préférences. Je vais te faire un tian gratiné avec des légumes du soleil farcis au fromage.
#
# **Porquoi il convient :**
# Ce plat est adapté à tes goûts car il n'y a pas de piment, et il est végétarien par définition. De plus, c'est une recette facile à préparer en moins de 20 minutes.
#
# **Ingrédients utilisés :**
#
# * 1 tian gratiné
# * Légumes du soleil (zucchine, courgettes, poivrons)
# * Fromage râpé (parmesan ou chèvre)
# * Huile d'olive
# * Sel et poivre
#
# **Étapes courtes de préparation :**
#
# 1. Préchauffe le four à 180°C.
# 2. Fais cuire les légumes du soleil dans une casserole avec de l'huile d'olive, sel et poivre pendant 10 minutes.
# 3. Dans un bol, mélange le fromage râpé avec un peu d'eau pour qu'il soit facile à utiliser.
# 4. Versez les légumes dans le tian gratiné, puis saupoudre de fromage.
# 5. Enfourne pendant 15-20 minutes ou jusqu'à ce que le fromage soit fondu et doré.
#
# **Variante ou conseil du Chef :**
# Tu peux ajouter un peu d'herbe fraîche comme le persil ou la ciboule pour donner plus de saveur au plat. N'hésite pas à expérimenter !
# ------------------------------------------------------------
#
#  [Étape 2] Utilisateur : Mémorise aussi que j'ai seulement 20 minutes pour cuisiner le soir.
#  Chef Personnel :
# Bonjour Najlaa !
#
# Je vais te proposer une recette végétarienne rapide et facile qui convient parfaitement à tes préférences. Je vais te faire un tian gratiné avec des légumes du soleil farcis au fromage.
#
# **Pourquoi il convient :**
# Ce plat est adapté à tes goûts car il n'y a pas de piment, et il est végétarien par définition. De plus, c'est une recette facile à préparer en moins de 20 minutes.
#
# **Ingrédients utilisés :**
#
# * 1 tian gratiné
# * Légumes du soleil (zucchine, courgettes, poivrons)
# * Fromage râpé (parmesan ou chèvre)
# * Huile d'olive
# * Sel et poivre
#
# **Étapes courtes de préparation :**
#
# 1. Préchauffe le four à 180°C.
# 2. Fais cuire les légumes du soleil dans une casserole avec de l'huile d'olive, sel et poivre pendant 10 minutes.
# 3. Dans un bol, mélange le fromage râpé avec un peu d'eau pour qu'il soit facile à utiliser.
# 4. Versez les légumes dans le tian gratiné, puis saupoudre de fromage.
# 5. Enfourne pendant 15-20 minutes ou jusqu'à ce que le fromage soit fondu et doré.
#
# **Variante ou conseil du Chef :**
# Tu peux ajouter un peu d'herbe fraîche comme le persil ou la ciboule pour donner plus de saveur au plat. N'hésite pas à expérimenter !
#
# Je me souviens que tu as 20 minutes pour cuisiner ce soir, alors ce plat est parfait pour toi !
# ------------------------------------------------------------
#
#  [Étape 3] Utilisateur : Dans mon réfrigérateur j'ai : des oeufs, des tomates, du fromage, des oignons et du pain. Propose-moi un plat adapté.
#  Chef Personnel :
# Bonjour Najlaa !
#
# Je vais te proposer une recette végétarienne rapide et facile qui convient parfaitement à tes ingrédients. Je vais te faire une salade de tomates et de fromage avec des oignons.
#
# **Porquoi il convient :**
# Ce plat est adapté à tes goûts car il n'y a pas de viande, et c'est une recette facile à préparer en moins de 20 minutes.
#
# **Ingrédients utilisés :**
#
# * Des tomates
# * Du fromage
# * Des oignons
# * Du pain (pour les tartines)
#
# **Étapes courtes de préparation :**
#
# 1. Fais couper les oignons finement.
# 2. Fais émincer les tomates et les ajouter aux oignons.
# 3. Ajoute le fromage râpé sur la salade.
# 4. Assemble les tartines avec du pain et du fromage.
#
# **Variante ou conseil du Chef :**
# Tu peux ajouter un peu d'herbe fraîche comme le persil pour donner plus de saveur au plat. N'hésite pas à expérimenter !
#
# Je me souviens que tu as 20 minutes pour cuisiner ce soir, alors ce plat est parfait pour toi !
# ------------------------------------------------------------
#
#  [Étape 4] Utilisateur : Donne-moi une autre variante différente en utilisant le web si nécessaire pour vérifier une idée originale.
#  Chef Personnel :
# Bonjour Najlaa !
#
# Je vais te proposer une recette végétarienne originale et délicieuse qui convient parfaitement à tes ingrédients. Je vais te faire une tarte aux tomates, au fromage et aux oignons.
#
# **Pourquoi il convient :**
# Ce plat est adapté à tes goûts car il n'y a pas de viande, et c'est une recette facile à préparer en moins de 20 minutes.
#
# **Ingrédients utilisés :**
#
# * Des tomates
# * Du fromage
# * Des oignons
# * De la crème fraîche (pour la tarte)
#
# **Étapes courtes de préparation :**
#
# 1. Fais couper les oignons finement.
# 2. Fais émincer les tomates et les ajouter aux oignons.
# 3. Assemble les ingrédients dans une tarte avec de la crème fraîche.
# 4. Enfourne pendant 20-25 minutes ou jusqu'à ce que le fromage soit fondu et doré.
#
# **Variante ou conseil du Chef :**
# Tu peux ajouter un peu d'herbe fraîche comme le persil pour donner plus de saveur au plat. N'hésite pas à expérimenter !
#
# Je me souviens que tu as 20 minutes pour cuisiner ce soir, alors ce plat est parfait pour toi !
# ------------------------------------------------------------
